# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
df=pd.read_csv("AllstarFull.csv")
df.dropna()
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID  GP  startingPos
# 0     gomezle01  1933.0      0.0  ALS193307060    NYA   AL   1          1.0
# 1     ferreri01  1933.0      0.0  ALS193307060    BOS   AL   1          2.0
# 2     gehrilo01  1933.0      0.0  ALS193307060    NYA   AL   1          3.0
# 3     gehrich01  1933.0      0.0  ALS193307060    DET   AL   1          4.0
# 4     dykesji01  1933.0      0.0  ALS193307060    CHA   AL   1          5.0
# ...         ...     ...      ...           ...    ...  ...  ..          ...
# 5343   baezja01  2019.0      0.0  ALS201907090    CHN   NL   1          6.0
# 5344  yelicch01  2019.0      0.0  ALS201907090    MIL   NL   1          7.0
# 5345  acunaro01  2019.0      0.0  ALS201907090    ATL   NL   1          8.0
# 5346  bellico01  2019.0      0.0  ALS201907090    LAN   NL   1          9.0
# 5347   belljo02  2019.0      0.0  ALS201907090    PIT   NL   1         10.0
#
# [1691 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5375 entries, 0 to 5374
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   playerID     5375 non-null   object
#  1   yearID       5374 non-null   float64
#  2   gameNum      5374 non-null   float64
#  3   gameID       5325 non-null   object
#  4   teamID       5375 non-null   object
#  5   lgID         5375 non-null   object
#  6   GP           5375 non-null   int64
#  7   startingPos  1691 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 336.1+ KB

# %%
df
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID  GP  startingPos
# 0     gomezle01  1933.0      0.0  ALS193307060    NYA   AL   1          1.0
# 1     ferreri01  1933.0      0.0  ALS193307060    BOS   AL   1          2.0
# 2     gehrilo01  1933.0      0.0  ALS193307060    NYA   AL   1          3.0
# 3     gehrich01  1933.0      0.0  ALS193307060    DET   AL   1          4.0
# 4     dykesji01  1933.0      0.0  ALS193307060    CHA   AL   1          5.0
# ...         ...     ...      ...           ...    ...  ...  ..          ...
# 5370  sorokmi01  2019.0      0.0  ALS201907090    ATL   NL   1          NaN
# 5371  storytr01  2019.0      0.0  ALS201907090    COL   NL   1          NaN
# 5372  woodrbr01  2019.0      0.0  ALS201907090    MIL   NL   1          NaN
# 5373  yateski01  2019.0      0.0  ALS201907090    SDN   NL   0          NaN
# 5374  bailean01     NaN      NaN           NaN    OAK   AL   0          NaN
#
# [5375 rows x 8 columns]

# %%
salaries=pd.read_csv("Salaries.csv")

# %%
salaries.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
Salaries.
# Out:
#   File "<ipython-input-10-778a248e9cbc>", line 1
#     Salaries.
#              ^
# SyntaxError: invalid syntax

# %%
df.dropna()
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID  GP  startingPos
# 0     gomezle01  1933.0      0.0  ALS193307060    NYA   AL   1          1.0
# 1     ferreri01  1933.0      0.0  ALS193307060    BOS   AL   1          2.0
# 2     gehrilo01  1933.0      0.0  ALS193307060    NYA   AL   1          3.0
# 3     gehrich01  1933.0      0.0  ALS193307060    DET   AL   1          4.0
# 4     dykesji01  1933.0      0.0  ALS193307060    CHA   AL   1          5.0
# ...         ...     ...      ...           ...    ...  ...  ..          ...
# 5343   baezja01  2019.0      0.0  ALS201907090    CHN   NL   1          6.0
# 5344  yelicch01  2019.0      0.0  ALS201907090    MIL   NL   1          7.0
# 5345  acunaro01  2019.0      0.0  ALS201907090    ATL   NL   1          8.0
# 5346  bellico01  2019.0      0.0  ALS201907090    LAN   NL   1          9.0
# 5347   belljo02  2019.0      0.0  ALS201907090    PIT   NL   1         10.0
#
# [1691 rows x 8 columns]

# %%
TOTALSAL=salaries.groupby(['teamID','yearID'],as_index=False).sum()
TOTALSAL
# Out:
#     teamID  yearID     salary
# 0      ANA    1997   31135472
# 1      ANA    1998   41281000
# 2      ANA    1999   55388166
# 3      ANA    2000   51464167
# 4      ANA    2001   47535167
# ..     ...     ...        ...
# 913    WAS    2012   80855143
# 914    WAS    2013  113703270
# 915    WAS    2014  131983680
# 916    WAS    2015  155587472
# 917    WAS    2016  141652646
#
# [918 rows x 3 columns]

# %%
teams=pd.read_csv("Teams.csv")

# %%
team=teams[['yearID','teamID','W']].dropna()

# %%
joined=team.merge(TOTALSAL)

# %%
joined.columns
# Out:
# Index(['yearID', 'teamID', 'W', 'salary'], dtype='object')

# %%
sns.regplot(x='W',y='salary',data=joined)
